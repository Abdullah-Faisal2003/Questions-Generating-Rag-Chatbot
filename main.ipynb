# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: fastapi==0.115.8 in c:\users\abdul\anaconda3\lib\site-packages (from fastapi[standard]==0.115.8->-r requirements.txt (line 1)) (0.115.8)
# Requirement already satisfied: uvicorn==0.34.0 in c:\users\abdul\anaconda3\lib\site-packages (from uvicorn[standard]==0.34.0->-r requirements.txt (line 2)) (0.34.0)
# Requirement already satisfied: python-multipart==0.0.20 in c:\users\abdul\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (0.0.20)
# Collecting pymupdf==1.25.3 (from -r requirements.txt (line 4))
#   Using cached pymupdf-1.25.3-cp39-abi3-win_amd64.whl.metadata (3.4 kB)
# Collecting langchain==0.3.19 (from -r requirements.txt (line 5))
#   Using cached langchain-0.3.19-py3-none-any.whl.metadata (7.9 kB)
# Collecting langchain-google-genai==2.0.10 (from -r requirements.txt (line 6))
#   Using cached langchain_google_genai-2.0.10-py3-none-any.whl.metadata (3.6 kB)
# Collecting langchain-community==0.3.18 (from -r requirements.txt (line 7))
#   Using cached langchain_community-0.3.18-py3-none-any.whl.metadata (2.4 kB)
# Collecting chromadb==0.6.3 (from -r requirements.txt (line 8))
#   Using cached chromadb-0.6.3-py3-none-any.whl.metadata (6.8 kB)
# Collecting sentence-transformers==3.4.1 (from -r requirements.txt (line 9))
#   Using cached sentence_transformers-3.4.1-py3-none-any.whl.metadata (10 kB)
# Collecting pillow==11.1.0 (from -r requirements.txt (line 10))
#   Using cached pillow-11.1.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: requests==2.32.3 in c:\users\abdul\anaconda3\lib\site-packages (from -r requirements.txt (line 11)) (2.32.3)
# Collecting python-dotenv==1.0.1 (from -r requirements.txt (line 12))
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in c:\users\abdul\anaconda3\lib\site-packages (from fastapi==0.115.8->fastapi[standard]==0.115.8->-r requirements.txt (line 1)) (0.45.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\abdul\anaconda3\lib\site-packages (from fastapi==0.115.8->fastapi[standard]==0.115.8->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\abdul\anaconda3\lib\site-packages (from fastapi==0.115.8->fastapi[standard]==0.115.8->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: click>=7.0 in c:\users\abdul\anaconda3\lib\site-packages (from uvicorn==0.34.0->uvicorn[standard]==0.34.0->-r requirements.txt (line 2)) (8.1.7)
# Requirement already satisfied: h11>=0.8 in c:\users\abdul\anaconda3\lib\site-packages (from uvicorn==0.34.0->uvicorn[standard]==0.34.0->-r requirements.txt (line 2)) (0.14.0)
# Collecting langchain-core<1.0.0,>=0.3.35 (from langchain==0.3.19->-r requirements.txt (line 5))
#   Using cached langchain_core-0.3.37-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.6 (from langchain==0.3.19->-r requirements.txt (line 5))
#   Using cached langchain_text_splitters-0.3.6-py3-none-any.whl.metadata (1.9 kB)
# Collecting langsmith<0.4,>=0.1.17 (from langchain==0.3.19->-r requirements.txt (line 5))
#   Using cached langsmith-0.3.9-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\abdul\anaconda3\lib\site-packages (from langchain==0.3.19->-r requirements.txt (line 5)) (2.0.34)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\abdul\anaconda3\lib\site-packages (from langchain==0.3.19->-r requirements.txt (line 5)) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\abdul\anaconda3\lib\site-packages (from langchain==0.3.19->-r requirements.txt (line 5)) (3.10.5)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\abdul\anaconda3\lib\site-packages (from langchain==0.3.19->-r requirements.txt (line 5)) (8.2.3)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\abdul\anaconda3\lib\site-packages (from langchain==0.3.19->-r requirements.txt (line 5)) (1.26.4)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai==2.0.10->-r requirements.txt (line 6))
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-generativeai<0.9.0,>=0.8.0 (from langchain-google-genai==2.0.10->-r requirements.txt (line 6))
#   Using cached google_generativeai-0.8.4-py3-none-any.whl.metadata (4.2 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community==0.3.18->-r requirements.txt (line 7))
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community==0.3.18->-r requirements.txt (line 7))
#   Using cached pydantic_settings-2.8.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community==0.3.18->-r requirements.txt (line 7))
#   Using cached httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting build>=1.0.3 (from chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Collecting chroma-hnswlib==0.7.6 (from chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached chroma_hnswlib-0.7.6.tar.gz (32 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting posthog>=2.4.0 (from chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached posthog-3.14.2-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached onnxruntime-1.20.1-cp312-cp312-win_amd64.whl.metadata (4.7 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached opentelemetry_api-1.30.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.30.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached opentelemetry_instrumentation_fastapi-0.51b0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached opentelemetry_sdk-1.30.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\abdul\anaconda3\lib\site-packages (from chromadb==0.6.3->-r requirements.txt (line 8)) (0.21.0)
# Collecting pypika>=0.48.9 (from chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\abdul\anaconda3\lib\site-packages (from chromadb==0.6.3->-r requirements.txt (line 8)) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\abdul\anaconda3\lib\site-packages (from chromadb==0.6.3->-r requirements.txt (line 8)) (7.4.0)
# Collecting importlib-resources (from chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting grpcio>=1.58.0 (from chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached grpcio-1.70.0-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# Collecting bcrypt>=4.0.1 (from chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached bcrypt-4.2.1-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in c:\users\abdul\anaconda3\lib\site-packages (from chromadb==0.6.3->-r requirements.txt (line 8)) (0.15.1)
# Collecting kubernetes>=28.1.0 (from chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached kubernetes-32.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting mmh3>=4.0.1 (from chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached mmh3-5.1.0-cp312-cp312-win_amd64.whl.metadata (16 kB)
# Collecting orjson>=3.9.12 (from chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached orjson-3.10.15-cp312-cp312-win_amd64.whl.metadata (42 kB)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\abdul\anaconda3\lib\site-packages (from chromadb==0.6.3->-r requirements.txt (line 8)) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\abdul\anaconda3\lib\site-packages (from chromadb==0.6.3->-r requirements.txt (line 8)) (13.7.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\abdul\anaconda3\lib\site-packages (from sentence-transformers==3.4.1->-r requirements.txt (line 9)) (4.48.3)
# Requirement already satisfied: torch>=1.11.0 in c:\users\abdul\anaconda3\lib\site-packages (from sentence-transformers==3.4.1->-r requirements.txt (line 9)) (2.6.0)
# Requirement already satisfied: scikit-learn in c:\users\abdul\anaconda3\lib\site-packages (from sentence-transformers==3.4.1->-r requirements.txt (line 9)) (1.5.1)
# Requirement already satisfied: scipy in c:\users\abdul\anaconda3\lib\site-packages (from sentence-transformers==3.4.1->-r requirements.txt (line 9)) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\abdul\anaconda3\lib\site-packages (from sentence-transformers==3.4.1->-r requirements.txt (line 9)) (0.28.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abdul\anaconda3\lib\site-packages (from requests==2.32.3->-r requirements.txt (line 11)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abdul\anaconda3\lib\site-packages (from requests==2.32.3->-r requirements.txt (line 11)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abdul\anaconda3\lib\site-packages (from requests==2.32.3->-r requirements.txt (line 11)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abdul\anaconda3\lib\site-packages (from requests==2.32.3->-r requirements.txt (line 11)) (2024.8.30)
# Requirement already satisfied: fastapi-cli>=0.0.5 in c:\users\abdul\anaconda3\lib\site-packages (from fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]==0.115.8->-r requirements.txt (line 1)) (0.0.7)
# Requirement already satisfied: jinja2>=3.1.5 in c:\users\abdul\anaconda3\lib\site-packages (from fastapi[standard]==0.115.8->-r requirements.txt (line 1)) (3.1.5)
# Requirement already satisfied: email-validator>=2.0.0 in c:\users\abdul\anaconda3\lib\site-packages (from fastapi[standard]==0.115.8->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: colorama>=0.4 in c:\users\abdul\appdata\roaming\python\python312\site-packages (from uvicorn[standard]==0.34.0->-r requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\abdul\anaconda3\lib\site-packages (from uvicorn[standard]==0.34.0->-r requirements.txt (line 2)) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\abdul\anaconda3\lib\site-packages (from uvicorn[standard]==0.34.0->-r requirements.txt (line 2)) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in c:\users\abdul\anaconda3\lib\site-packages (from uvicorn[standard]==0.34.0->-r requirements.txt (line 2)) (14.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\abdul\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.19->-r requirements.txt (line 5)) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\abdul\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.19->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\abdul\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.19->-r requirements.txt (line 5)) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\abdul\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.19->-r requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\abdul\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.19->-r requirements.txt (line 5)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\abdul\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.19->-r requirements.txt (line 5)) (1.11.0)
# Requirement already satisfied: packaging>=19.1 in c:\users\abdul\appdata\roaming\python\python312\site-packages (from build>=1.0.3->chromadb==0.6.3->-r requirements.txt (line 8)) (24.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.18->-r requirements.txt (line 7))
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.18->-r requirements.txt (line 7))
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\abdul\anaconda3\lib\site-packages (from email-validator>=2.0.0->fastapi[standard]==0.115.8->-r requirements.txt (line 1)) (2.7.0)
# Requirement already satisfied: rich-toolkit>=0.11.1 in c:\users\abdul\anaconda3\lib\site-packages (from fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]==0.115.8->-r requirements.txt (line 1)) (0.13.2)
# Collecting google-ai-generativelanguage==0.6.15 (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.10->-r requirements.txt (line 6))
#   Using cached google_ai_generativelanguage-0.6.15-py3-none-any.whl.metadata (5.7 kB)
# Collecting google-api-core (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.10->-r requirements.txt (line 6))
#   Using cached google_api_core-2.24.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-api-python-client (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.10->-r requirements.txt (line 6))
#   Using cached google_api_python_client-2.161.0-py2.py3-none-any.whl.metadata (6.7 kB)
# Collecting google-auth>=2.15.0 (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.10->-r requirements.txt (line 6))
#   Using cached google_auth-2.38.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: protobuf in c:\users\abdul\anaconda3\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.10->-r requirements.txt (line 6)) (4.25.3)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.10->-r requirements.txt (line 6))
#   Using cached proto_plus-1.26.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: anyio in c:\users\abdul\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb==0.6.3->-r requirements.txt (line 8)) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\abdul\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb==0.6.3->-r requirements.txt (line 8)) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\abdul\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb==0.6.3->-r requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: filelock in c:\users\abdul\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers==3.4.1->-r requirements.txt (line 9)) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\abdul\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers==3.4.1->-r requirements.txt (line 9)) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\abdul\anaconda3\lib\site-packages (from jinja2>=3.1.5->fastapi[standard]==0.115.8->-r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\abdul\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb==0.6.3->-r requirements.txt (line 8)) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\abdul\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb==0.6.3->-r requirements.txt (line 8)) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\abdul\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.6.3->-r requirements.txt (line 8)) (1.8.0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\abdul\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.35->langchain==0.3.19->-r requirements.txt (line 5)) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\abdul\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain==0.3.19->-r requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\abdul\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain==0.3.19->-r requirements.txt (line 5)) (0.23.0)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: sympy in c:\users\abdul\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb==0.6.3->-r requirements.txt (line 8)) (1.13.1)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\users\abdul\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb==0.6.3->-r requirements.txt (line 8)) (7.0.1)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached googleapis_common_protos-1.68.0-py2.py3-none-any.whl.metadata (5.1 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.30.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached opentelemetry_exporter_otlp_proto_common-1.30.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.30.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached opentelemetry_proto-1.30.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting protobuf (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.10->-r requirements.txt (line 6))
#   Using cached protobuf-5.29.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting opentelemetry-instrumentation-asgi==0.51b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached opentelemetry_instrumentation_asgi-0.51b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation==0.51b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached opentelemetry_instrumentation-0.51b0-py3-none-any.whl.metadata (6.3 kB)
# Collecting opentelemetry-semantic-conventions==0.51b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached opentelemetry_semantic_conventions-0.51b0-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-util-http==0.51b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached opentelemetry_util_http-0.51b0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\abdul\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3->-r requirements.txt (line 8)) (1.14.1)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\abdul\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi==0.115.8->fastapi[standard]==0.115.8->-r requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\abdul\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi==0.115.8->fastapi[standard]==0.115.8->-r requirements.txt (line 1)) (2.20.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\abdul\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb==0.6.3->-r requirements.txt (line 8)) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\abdul\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->chromadb==0.6.3->-r requirements.txt (line 8)) (2.18.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\abdul\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.3.19->-r requirements.txt (line 5)) (3.0.1)
# Requirement already satisfied: networkx in c:\users\abdul\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers==3.4.1->-r requirements.txt (line 9)) (3.3)
# Requirement already satisfied: setuptools in c:\users\abdul\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers==3.4.1->-r requirements.txt (line 9)) (75.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\abdul\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.6.3->-r requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\abdul\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers==3.4.1->-r requirements.txt (line 9)) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\abdul\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers==3.4.1->-r requirements.txt (line 9)) (0.5.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\abdul\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb==0.6.3->-r requirements.txt (line 8)) (1.5.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\abdul\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers==3.4.1->-r requirements.txt (line 9)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\abdul\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers==3.4.1->-r requirements.txt (line 9)) (3.5.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\abdul\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.10->-r requirements.txt (line 6)) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\abdul\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.10->-r requirements.txt (line 6)) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.10->-r requirements.txt (line 6))
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\abdul\anaconda3\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==0.6.3->-r requirements.txt (line 8)) (3.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\abdul\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.35->langchain==0.3.19->-r requirements.txt (line 5)) (2.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\abdul\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb==0.6.3->-r requirements.txt (line 8)) (0.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\abdul\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.18->-r requirements.txt (line 7)) (1.0.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting httplib2<1.dev0,>=0.19.0 (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.10->-r requirements.txt (line 6))
#   Using cached httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.10->-r requirements.txt (line 6))
#   Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.10->-r requirements.txt (line 6))
#   Using cached uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.10->-r requirements.txt (line 6))
#   Using cached grpcio_status-1.70.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\abdul\anaconda3\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.10->-r requirements.txt (line 6)) (3.1.2)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb==0.6.3->-r requirements.txt (line 8))
#   Using cached pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\abdul\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai==2.0.10->-r requirements.txt (line 6)) (0.4.8)
# Using cached pymupdf-1.25.3-cp39-abi3-win_amd64.whl (16.5 MB)
# Using cached langchain-0.3.19-py3-none-any.whl (1.0 MB)
# Using cached langchain_google_genai-2.0.10-py3-none-any.whl (41 kB)
# Using cached langchain_community-0.3.18-py3-none-any.whl (2.5 MB)
# Using cached chromadb-0.6.3-py3-none-any.whl (611 kB)
# Using cached sentence_transformers-3.4.1-py3-none-any.whl (275 kB)
# Using cached pillow-11.1.0-cp312-cp312-win_amd64.whl (2.6 MB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Using cached bcrypt-4.2.1-cp39-abi3-win_amd64.whl (153 kB)
# Using cached build-1.2.2.post1-py3-none-any.whl (22 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached google_generativeai-0.8.4-py3-none-any.whl (175 kB)
# Using cached google_ai_generativelanguage-0.6.15-py3-none-any.whl (1.3 MB)
# Using cached grpcio-1.70.0-cp312-cp312-win_amd64.whl (4.3 MB)
# Using cached httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Using cached kubernetes-32.0.1-py2.py3-none-any.whl (2.0 MB)
# Using cached langchain_core-0.3.37-py3-none-any.whl (413 kB)
# Using cached langchain_text_splitters-0.3.6-py3-none-any.whl (31 kB)
# Using cached langsmith-0.3.9-py3-none-any.whl (333 kB)
# Using cached mmh3-5.1.0-cp312-cp312-win_amd64.whl (41 kB)
# Using cached onnxruntime-1.20.1-cp312-cp312-win_amd64.whl (11.3 MB)
# Using cached opentelemetry_api-1.30.0-py3-none-any.whl (64 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.30.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.30.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.30.0-py3-none-any.whl (55 kB)
# Using cached opentelemetry_instrumentation_fastapi-0.51b0-py3-none-any.whl (12 kB)
# Using cached opentelemetry_instrumentation-0.51b0-py3-none-any.whl (30 kB)
# Using cached opentelemetry_instrumentation_asgi-0.51b0-py3-none-any.whl (16 kB)
# Using cached opentelemetry_semantic_conventions-0.51b0-py3-none-any.whl (177 kB)
# Using cached opentelemetry_util_http-0.51b0-py3-none-any.whl (7.3 kB)
# Using cached opentelemetry_sdk-1.30.0-py3-none-any.whl (118 kB)
# Using cached orjson-3.10.15-cp312-cp312-win_amd64.whl (133 kB)
# Using cached posthog-3.14.2-py2.py3-none-any.whl (73 kB)
# Using cached pydantic_settings-2.8.0-py3-none-any.whl (30 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Using cached durationpy-0.9-py3-none-any.whl (3.5 kB)
# Using cached google_api_core-2.24.1-py3-none-any.whl (160 kB)
# Using cached google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
# Using cached googleapis_common_protos-1.68.0-py2.py3-none-any.whl (164 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached protobuf-5.29.3-cp310-abi3-win_amd64.whl (434 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Using cached google_api_python_client-2.161.0-py2.py3-none-any.whl (12.9 MB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached asgiref-3.8.1-py3-none-any.whl (23 kB)
# Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Using cached httplib2-0.22.0-py3-none-any.whl (96 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached proto_plus-1.26.0-py3-none-any.whl (50 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Using cached grpcio_status-1.70.0-py3-none-any.whl (14 kB)
# Using cached pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Building wheels for collected packages: chroma-hnswlib
#   Building wheel for chroma-hnswlib (pyproject.toml): started
#   Building wheel for chroma-hnswlib (pyproject.toml): finished with status 'error'
# Failed to build chroma-hnswlib
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for chroma-hnswlib (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [5 lines of output]
#       running bdist_wheel
#       running build
#       running build_ext
#       building 'hnswlib' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for chroma-hnswlib
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (chroma-hnswlib)

# %%
import io
import base64
import time
import warnings
import numpy as np
import pymupdf
from PIL import Image
from langchain.schema import HumanMessage, StrOutputParser
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_google_genai import ChatGoogleGenerativeAI
from sentence_transformers import SentenceTransformer
import chromadb
from chromadb.config import Settings
from dotenv import load_dotenv
warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 6
#       4 import warnings
#       5 import numpy as np
# ----> 6 import pymupdf
#       7 from PIL import Image
#       8 from langchain.schema import HumanMessage, StrOutputParser
#
# ModuleNotFoundError: No module named 'pymupdf'

# %%
load_dotenv()
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
chroma_db_path = os.getenv("CHROMA_DB_PATH")
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash-exp")

# %%
def encode_image_to_base64(image):
    """Convert PIL Image to base64 string with data URI"""
    buffered = io.BytesIO()
    image.save(buffered, format="PNG")
    img_str = base64.b64encode(buffered.getvalue()).decode('utf-8')
    return f"data:image/png;base64,{img_str}"

# %%
# Convert image to base64 with proper data URI
def generate_text_from_image(image):
  # Define the prompt
  template = f"""
  You are an expert at extracting and explaining the content of an image.
  - Extract **all textual content** from the image.
  - Detect and describe **tables, graphs, charts, and their relationships**.
  - If the image contains a **pipeline**, explain its **step-by-step process**.
  - Maintain formatting for tables and key visual structures.
  """
  messages = [HumanMessage(content=[{"type": "text", "text": template}, {"type": "image_url", "image_url": image}])]
  response = llm(messages)
  return response.content

# %%
# Open the PDF
doc = pymupdf.open("Lecture 2 - Deep Feedforward Networks.pdf")
texts = []
page_content = []


# Loop through each page
for page_num in range(len(doc)):
    page = doc.load_page(page_num)

    # Extract text from the page
    text = page.get_text()
    texts.append(text)  # Store the text for each page

    # Get the images on the page
    img_list = page.get_images(full=True)

    for img_index, img in enumerate(img_list):
        xref = img[0]  # XREF of the image
        base_image = doc.extract_image(xref)
        image_bytes = base_image["image"]  # Image bytes

        # Save the image
        image = Image.open(io.BytesIO(image_bytes))
        image_base64 = encode_image_to_base64(image)

        # Introduce error handling and rate limiting
        try:
            gen_text = generate_text_from_image(image_base64)
            text += gen_text
        except Exception as e:
            print(f"Error processing image on page {page_num}, image index {img_index}: {e}")

        # delay to respect rate limits
        time.sleep(10)

    page_content.append(text)

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 2000,
    chunk_overlap  = 300
)
combined_text = " ".join(page_content)

# Now split the combined text
texts = text_splitter.split_text(combined_text)

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
def get_text_embedding(text):
  embedding = model.encode(text)
  return embedding
embeddings_text = []
# Loop through each page to extract text and images, then embed them
for text in texts:
    # Extract text and embed it
    text_embedding = get_text_embedding(text)  # Get text embedding
    embeddings_text.append(text_embedding)  # Store in the dictionary

# %%
chroma_settings = Settings(
    chroma_db_impl="duckdb+parquet",  # Use DuckDB with Parquet for persistence
    persist_directory=chroma_db_path,  # Use the path from .env
    anonymized_telemetry=False        # Disable telemetry (optional)
)
# Initialize ChromaDB client
client = chromadb.Client(chroma_settings)

# Create or load a collection
text_collection = client.get_or_create_collection(name="pdf_text_embedding")

# %%
for page_num, page_text in enumerate(page_content):
    combined_text = " ".join(page_text)
    texts = text_splitter.split_text(combined_text)

    # Add metadata for each chunk
    for i, text in enumerate(texts):
        text_embedding = embeddings_text[i]
        text_collection.add(
            documents=[text],
            embeddings=[text_embedding],
            metadatas=[{"type": "text", "page_number": page_num + 1}],
            ids=[f"page_{page_num + 1}_text_{i + 1}"]
        )

# %%
def generate_questions(query):
    text_collections = client.get_collection("pdf_text_embedding")
    content = text_collections.get()["documents"]

    # Template for generating questions from the PDF content
# Template for generating questions from the PDF content
    template = f"""
    You are an AI assistant that generates Multiple Choice Questions (MCQs) based on the content of a given PDF document.

    ### User Query:
    "{query}"

    ### Context:
    The PDF document contains the following content (excluding the lecture overview):
    {content}

    ### Instructions:
    - Carefully analyze the content of the provided PDF, but **ignore the lecture overview** as it may contain titles that will be explained later.
    - Generate MCQs based on the textual content, ensuring that the questions are **specific**, **clear**, and **focused on content** without referencing any metadata of the PDF or the university.

    ### Output Format:
    Provide a list of MCQs like this:
    1. Question: What was the total increase in sales between Q1 and Q2?
      - a) $1,000
      - b) $1,500
      - c) $2,000
      - d) $2,500
      - Correct answer: c)

    Now, generate the MCQs:
    """


    llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash-exp")
    messages = [HumanMessage(content=template)]  # Create a HumanMessage object
    response = llm(messages)  # Call the llm with the list of messages
    return [{"generated_text": response.content}]  # Extract the content from the response

query = "I want 40 questions"
result = generate_questions(query)
print(StrOutputParser().parse(result[0]['generated_text']))
# Out:
# Okay, here are 40 Multiple Choice Questions (MCQs) based on the provided content from the PDF document, excluding the lecture overview:
#
# 1.  Question: What is the primary function of a feedforward network?
#     - a) To learn the value of parameters resulting in the worst function approximation.
#     - b) To define a mapping and approximate some function.
#     - c) To avoid parameterization.
#     - d) To create feedback connections.
#     - Correct answer: b)
#
# 2.  Question: What is a key characteristic of deep feedforward networks regarding connections?
#     - a) They include feedback connections.
#     - b) They have no connections.
#     - c) They have no feedback connections.
#     - d) They primarily utilize recurrent connections.
#     - Correct answer: c)
#
# 3.  Question: In the context of deep learning, what does a "module" represent?
#     - a) A type of loss function.
#     - b) A building block, transformation, or function.
#     - c) A specific optimization algorithm.
#     - d) A method for data augmentation.
#     - Correct answer: b)
#
# 4.  Question: What is a key requirement for activation functions in the hierarchies of modules?
#     - a) They must be second-order differentiable.
#     - b) They must be first-order differentiable (almost) everywhere.
#     - c) They must be non-differentiable.
#     - d) They must contain cycles.
#     - Correct answer: b)
#
# 5.  Question: What is the strategy of deep learning related to the function φ?
#     - a) To avoid learning φ.
#     - b) To learn φ, where y = f(x; θ, w) = φ(x; θ)Tw.
#     - c) To find a non-good representation.
#     - d) To make the training problem convex.
#     - Correct answer: b)
#
# 6.  Question: What does the image suggest about combining multiple inputs and modalities?
#     - a) It is nonsensical and should not be done.
#     - b) It makes sense when we have good knowledge of problem domain.
#     - c) It is only useful for image processing.
#     - d) It complicates the model unnecessarily.
#     - Correct answer: b)
#
# 7.  Question: What is the key idea behind non-linear feature learning perspective?
#     - a) To solve non-linear problems directly with linear models.
#     - b) To apply linear model to a transformed input φ(x).
#     - c) To avoid using non-linear models.
#     - d) To remove features from the input.
#     - Correct answer: b)
#
# 8.  Question: According to the material, what is the goal when finding θ corresponding to a good representation?
#     - a) To make the data linearly inseparable.
#     - b) To make the data linearly separable (in the case of classification).
#     - c) To complicate the training problem.
#     - d) To avoid generalizations.
#     - Correct answer: b)
#
# 9.  Question: What is a major difference between feedforward and recurrent neural networks?
#     - a) Feedforward networks use feedback connections.
#     - b) Recurrent neural networks do not have feedback connections.
#     - c) Feedforward networks do not have feedback connections, while recurrent networks do.
#     - d) There is no difference.
#     - Correct answer: c)
#
# 10. Question: What is the term for a function that limits the output range of a node?
#     - a) A linear function.
#     - b) A classification function.
#     - c) A squashing function.
#     - d) An optimization function.
#     - Correct answer: c)
#
# 11. Question: According to the text, what is a common choice for non-linearity?
#     - a) A sigmoid function.
#     - b) A Tanh function.
#     - c) A ReLU.
#     - d) A linear Function.
#     - Correct answer: c)
#
# 12. Question: What is a potential problem with ReLU units?
#     - a) Gradient Saturation.
#     - b) They are always zero-centered.
#     - c) They are scale-invariant.
#     - d) Dead neurons.
#     - Correct answer: d)
#
# 13. Question: What is a major advantage of ReLU units compared to Sigmoid units?
#     - a) They are always bounded.
#     - b) They have fewer vanishing gradient problems.
#     - c) They have saturation in both directions.
#     - d) They are less efficient to compute.
#     - Correct answer: b)
#
# 14. Question: What is one way to address the issue of dead neurons in ReLU networks?
#     - a) Decrease learning rates.
#     - b) Increase learning rates.
#     - c) Use sigmoid activations.
#     - d) Decrease the number of layers.
#     - Correct answer: b)
#
# 15. Question: What does a Leaky ReLU allow when the unit is not active?
#     - a) Zero gradient
#     - b) A small, positive gradient.
#     - c) A large, negative gradient.
#     - d) A gradient of 1.
#     - Correct answer: b)
#
# 16. Question: What is the range of the Tanh activation function?
#     - a) [0, 1]
#     - b) [-1, 0]
#     - c) [-1, +1]
#     - d) [0, infinity]
#     - Correct answer: c)
#
# 17. Question: What is a disadvantage of using Sigmoid activation functions in hidden layers?
#     - a) They are not differentiable.
#     - b) They lead to faster training.
#     - c) They can cause vanishing gradients.
#     - d) They are zero centered.
#     - Correct answer: c)
#
# 18. Question: What is a typical use case for Sigmoid functions, according to the text?
#     - a) Hidden layers to prevent vanishing gradients.
#     - b) Middle layers to get stronger gradients.
#     - c) Outputs to emulate probabilities.
#     - d) As a replacement for ReLU.
#     - Correct answer: c)
#
# 19. Question: What is the purpose of the softmax function?
#     - a) To create a linear output
#     - b) To output a probability distribution.
#     - c) To create overconfident predictions.
#     - d) To emulate recurrent structures.
#     - Correct answer: b)
#
# 20. Question: What is the key objective when using gradient-based optimizers to train neural networks?
#     - a) To guarantee convergence.
#     - b) To ensure loss function is convex.
#     - c) To iteratively find parameters.
#     - d) To make the loss function non-convex.
#     - Correct answer: c)
#
# 21. Question: What is the main point about cost functions?
#     - a) They describe what the model should do.
#     - b) They should be flat to avoid large gradients.
#     - c) They need to saturate.
#     - d) They should be complex.
#     - Correct answer: a)
#
# 22. Question: What is a property of cost functions that can undermine learning?
#     - a) They are linear.
#     - b) They are convex.
#     - c) They saturate (become very flat).
#     - d) They are small.
#     - Correct answer: c)
#
# 23. Question: What does the diagram of a single artificial neuron show?
#     - a) The complete architecture of a neural network.
#     - b) The flow of information from inputs to output.
#     - c) A comparison of different activation functions.
#     - d) The optimization algorithm used to train the neuron.
#     - Correct answer: b)
#
# 24. Question: In a single artificial neuron, what happens to the input signals?
#     - a) They are averaged.
#     - b) They are multiplied by corresponding weights.
#     - c) They are ignored.
#     - d) They are exponentiated.
#     - Correct answer: b)
#
# 25. Question: What is the role of the bias input in an artificial neuron?
#     - a) To normalize the input signals.
#     - b) To prevent the neuron from learning an offset.
#     - c) To allow the neuron to learn an offset.
#     - d) To increase the speed of computation.
#     - Correct answer: c)
#
# 26. Question: What is the purpose of the activation function in an artificial neuron?
#     - a) To sum the weighted inputs.
#     - b) To introduce non-linearity.
#     - c) To normalize the output.
#     - d) To reduce the number of inputs.
#     - Correct answer: b)
#
# 27. Question: How are neural networks organized?
#     - a) In a circular fashion.
#     - b) In a random order.
#     - c) In layers connected in a chain structure.
#     - d) As a single, monolithic block.
#     - Correct answer: c)
#
# 28. Question: What does the text suggest about the number of hidden units in a neural network?
#     - a) More hidden units always lead to better performance.
#     - b) The training algorithm will always be able to learn the function.
#     - c) The network might choose the wrong function due to overfitting.
#     - d) The number of hidden units is irrelevant.
#     - Correct answer: c)
#
# 29. Question: What is a characteristic of linear models like logistic regression?
#     - a) They have unlimited capacity.
#     - b) They are non-convex.
#     - c) They have limited capacity and can be fit efficiently.
#     - d) They are difficult to fit.
#     - Correct answer: c)
#
# 30. Question: How can linear models be extended to non-linear models?
#     - a) By removing the linear component.
#     - b) By applying the linear model to a transformed input.
#     - c) By using complex optimization algorithms.
#     - d) By making the model convex.
#     - Correct answer: b)
#
# 31. Question: What is the role of the "Fast(er) R-CNN" in the visual-linguistic model described?
#     - a) To tokenize the input text.
#     - b) To process the text tokens.
#     - c) To identify regions of interest in the image and extract features.
#     - d) To generate captions for the image.
#     - Correct answer: c)
#
# 32. Question: What is the purpose of the `[MASK]` token in the example input sequence?
#     - a) To separate segments.
#     - b) To denote image regions.
#     - c) To indicate a word to be predicted.
#     - d) To denote the end of the sequence.
#     - Correct answer: c)
#
# 33. Question: If the model is specified as p_model(y|x) = N(y; f(x; θ), I), what cost function can be recovered?
#     - a) Cross-entropy
#     - b) KL-divergence
#     - c) Squared Error
#     - d) Negative log-likelihood
#     - Correct answer: c)
#
# 34. Question: According to the text, what is the relationship between backpropagation and the chain rule?
#     - a) They are unrelated concepts.
#     - b) Backpropagation is a specific algorithm to compute the chain rule.
#     - c) The chain rule is an inefficient approach for backpropagation.
#     - d) Backpropagation avoids the chain rule.
#     - Correct answer: b)
#
# 35. Question: What does the Jacobian determinant measure for square matrices?
#     - a) The slope of the function.
#     - b) The ratio of areas.
#     - c) The curvature of the function.
#     - d) The complexity of the model.
#     - Correct answer: b)
#
# 36. Question: What does the term "Vec(M)" represent in the context of taking gradients with index notation for matrices/vectors?
#     - a) The variance of matrix M.
#     - b) The vectorized form of matrix M.
#     - c) The determinant of matrix M.
#     - d) The inverse of matrix M.
#     - Correct answer: b)
#
# 37. Question: What does the equation  𝑑 ℎ / 𝑑 𝒙 =   𝛻 𝒙 ℎ =   [   𝜕 ℎ / 𝜕 𝑥 1 ,   …   ,   𝜕 ℎ / 𝜕 𝑥 𝑇  ] represent?
#     - a) The Hessian Matrix
#     - b) The Lagrangian.
#     - c) The gradient of h with respect to the vector x.
#     - d) The Jacobian.
#     - Correct answer: c)
#
# 38. Question: What does the text say about the relationship between back-propogation and the brain?
#     - a) It is exactly how the brain learns.
#     - b) It is similar to how the brain learns.
#     - c) It is thought to be impossible in the brain to have the required connectivity.
#     - d) It is not related to the brain at all.
#     - Correct answer: c)
#
# 39. Question: What is the background color of the University of Amsterdam logo in the extracted information?
#     - a) White
#     - b) Blue
#     - c) Black
#     - d) Red
#     - Correct answer: c)
#
# 40. Question: According to the text, what is the default recommendation for activation functions in modern neural networks?
#     - a) Sigmoid
#     - b) Tanh
#     - c) ReLU or GELU
#     - d) Linear
#     - Correct answer: c)
